# %%
import pandas as pd

# %%
# df = pd.read_excel("../data/Final_data_01_24_2022_Daniel_GMHI2.xlsx", engine="openpyxl")
# df

# %%
# df.to_csv("../data/raw.csv")

# %%
df = pd.read_csv("../data/raw.csv", index_col=0)
df
# Out:
# /Users/daniel/opt/anaconda3/envs/data/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (11,12,13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Study_ID    Author (year) BoiProject ID Sample Accession       RunID  \
# 0        GMHI-23  Vogtmann (2016)    PRJEB12449     SAMEA3879547  ERR1293689
# 1        GMHI-23  Vogtmann (2016)    PRJEB12449     SAMEA3879551  ERR1293705
# 2        GMHI-23  Vogtmann (2016)    PRJEB12449     SAMEA3879543  ERR1293673
# 3        GMHI-23  Vogtmann (2016)    PRJEB12449     SAMEA3879565  ERR1293761
# 4        GMHI-23  Vogtmann (2016)    PRJEB12449     SAMEA3879546  ERR1293685
# ...          ...              ...           ...              ...         ...
# 12527    GMHI-17     Zhang (2015)     PRJEB6997     SAMEA2737871   ERR589866
# 12528    GMHI-17     Zhang (2015)     PRJEB6997     SAMEA2737819   ERR589814
# ...

# %%
df['PHENOTYPE:Healthy_Nonhealthy'].value_counts()
# Out:
# Healthy       6603
# Nonhealthy    5929
# Name: PHENOTYPE:Healthy_Nonhealthy, dtype: int64

# %%
y = df['PHENOTYPE:Healthy_Nonhealthy'] == "Healthy"

# %%
species = list(filter(lambda x : "s__" in x and "t__" not in x, df.columns))

# %%
X = df[species]

# %%
X.to_csv("../data/X.csv")
y.to_csv("../data/y.csv")
